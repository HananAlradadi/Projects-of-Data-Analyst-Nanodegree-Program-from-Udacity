# %% [markdown]
# # WeRateDogs Twitter Data: Visualization Analyses Report

# %%
from IPython.display import Image

# %% [markdown]
# # Visualization 1 :
# ## Find the top 10 of dogs names with retweet count

# %% [markdown]
# # In the Visualization part, we removed the None values, and removed the incorrect dog names ('such', 'an', 'the', 'just', 'by', 'a', 'mad', 'old', 'space', 'quite', 'actually', 'infuriating', 'all', 'officially', 'my', 'unacceptable', 'incredibly','not', '0', 'life', 'one', 'his', 'very') we want to find out the top 10 of dog names which are with retweet count.

# %%
Image(filename='top10_dog_names.png')

# %% [markdown]
# # As we can see from the chart the name of the dog ("Frankin") is top 1 of dog names.

# %% [markdown]
# # Visualization 2 :
# ## Popular dog stages with numbers

# %%
Image(filename='dog_stages.png')

# %% [markdown]
# # Visualization 3 :
# ## Scatter plot digeam represents the relationship between favorites and retweets

# %%
Image(filename='Retweets_and_favorite.png')

# %% [markdown]
# # Based on the digeam above, there is a strong relationship between favorites and retweets

# %%
# !jupyter nbconvert act_report.ipynb --to slides -post serve --no-input -template output-toggle.tpl
# Out:
# [NbConvertApp] WARNING | Unrecognized alias: 'post', it will have no effect.
# [NbConvertApp] WARNING | Unrecognized alias: 'template', it will have no effect.
# [NbConvertApp] Converting notebook act_report.ipynb to slides
# [NbConvertApp] Writing 617541 bytes to act_report.slides.html
